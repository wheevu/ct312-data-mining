# %% [markdown]
# # Week 2: GitHub Issue Exploration
#
# First look at the structure and labels of GitHub issues from selected repositories.

# %%
import pandas as pd
import requests
import json

# %%
# TODO: fetch a sample of issues from a public repo
# url = "https://api.github.com/repos/owner/repo/issues"
# response = requests.get(url)
# issues = response.json()

# %%
# TODO: explore label distributions, data types, missing values

# %%
# TODO: save raw data to data/raw/ for reuse
